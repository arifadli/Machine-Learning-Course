# %% [markdown]
# # **Install Library**

# %%
# !pip install geopandas
# !pip install simple_colors
# !pip install cartopy
# !pip install sklearn
# !pip install libpysal
# !pip install matplotlib basemap
# !pip install esda
# Out:
# Requirement already satisfied: geopandas in /usr/local/lib/python3.12/dist-packages (1.1.1)
# Requirement already satisfied: numpy>=1.24 in /usr/local/lib/python3.12/dist-packages (from geopandas) (2.0.2)
# Requirement already satisfied: pyogrio>=0.7.2 in /usr/local/lib/python3.12/dist-packages (from geopandas) (0.11.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from geopandas) (25.0)
# Requirement already satisfied: pandas>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from geopandas) (2.2.2)
# Requirement already satisfied: pyproj>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from geopandas) (3.7.2)
# Requirement already satisfied: shapely>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from geopandas) (2.1.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.0.0->geopandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.0.0->geopandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.0.0->geopandas) (2025.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from pyogrio>=0.7.2->geopandas) (2025.11.12)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=2.0.0->geopandas) (1.17.0)
# Requirement already satisfied: simple_colors in /usr/local/lib/python3.12/dist-packages (0.1.5)
# Requirement already satisfied: cartopy in /usr/local/lib/python3.12/dist-packages (0.25.0)
# Requirement already satisfied: numpy>=1.23 in /usr/local/lib/python3.12/dist-packages (from cartopy) (2.0.2)
# Requirement already satisfied: matplotlib>=3.6 in /usr/local/lib/python3.12/dist-packages (from cartopy) (3.10.0)
# Requirement already satisfied: shapely>=2.0 in /usr/local/lib/python3.12/dist-packages (from cartopy) (2.1.2)
# Requirement already satisfied: packaging>=21 in /usr/local/lib/python3.12/dist-packages (from cartopy) (25.0)
# Requirement already satisfied: pyshp>=2.3 in /usr/local/lib/python3.12/dist-packages (from cartopy) (2.3.1)
# Requirement already satisfied: pyproj>=3.3.1 in /usr/local/lib/python3.12/dist-packages (from cartopy) (3.7.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.6->cartopy) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.6->cartopy) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.6->cartopy) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.6->cartopy) (1.4.9)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.6->cartopy) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.6->cartopy) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.6->cartopy) (2.9.0.post0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from pyproj>=3.3.1->cartopy) (2025.11.12)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3.6->cartopy) (1.17.0)
# Collecting sklearn
#   Using cached sklearn-0.0.post12.tar.gz (2.6 kB)
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Preparing metadata (setup.py) ... error
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.
# Requirement already satisfied: libpysal in /usr/local/lib/python3.12/dist-packages (4.13.0)
# Requirement already satisfied: beautifulsoup4>=4.10 in /usr/local/lib/python3.12/dist-packages (from libpysal) (4.13.5)
# Requirement already satisfied: geopandas>=0.10.0 in /usr/local/lib/python3.12/dist-packages (from libpysal) (1.1.1)
# Requirement already satisfied: numpy>=1.22 in /usr/local/lib/python3.12/dist-packages (from libpysal) (2.0.2)
# Requirement already satisfied: packaging>=22 in /usr/local/lib/python3.12/dist-packages (from libpysal) (25.0)
# Requirement already satisfied: pandas>=1.4 in /usr/local/lib/python3.12/dist-packages (from libpysal) (2.2.2)
# Requirement already satisfied: platformdirs>=2.0.2 in /usr/local/lib/python3.12/dist-packages (from libpysal) (4.5.0)
# Requirement already satisfied: requests>=2.27 in /usr/local/lib/python3.12/dist-packages (from libpysal) (2.32.4)
# Requirement already satisfied: scipy>=1.8 in /usr/local/lib/python3.12/dist-packages (from libpysal) (1.16.3)
# Requirement already satisfied: shapely>=2.0.1 in /usr/local/lib/python3.12/dist-packages (from libpysal) (2.1.2)
# Requirement already satisfied: scikit-learn>=1.1 in /usr/local/lib/python3.12/dist-packages (from libpysal) (1.6.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4>=4.10->libpysal) (2.8)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4>=4.10->libpysal) (4.15.0)
# Requirement already satisfied: pyogrio>=0.7.2 in /usr/local/lib/python3.12/dist-packages (from geopandas>=0.10.0->libpysal) (0.11.1)
# Requirement already satisfied: pyproj>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from geopandas>=0.10.0->libpysal) (3.7.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.4->libpysal) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.4->libpysal) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.4->libpysal) (2025.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.27->libpysal) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.27->libpysal) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.27->libpysal) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.27->libpysal) (2025.11.12)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.1->libpysal) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.1->libpysal) (3.6.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=1.4->libpysal) (1.17.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (3.10.0)
# Requirement already satisfied: basemap in /usr/local/lib/python3.12/dist-packages (2.0.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: basemap_data<3.0,>=2.0 in /usr/local/lib/python3.12/dist-packages (from basemap) (2.0.0)
# Requirement already satisfied: pyproj<3.8,>=3.0 in /usr/local/lib/python3.12/dist-packages (from basemap) (3.7.2)
# Requirement already satisfied: pyshp<2.4,>=2.0 in /usr/local/lib/python3.12/dist-packages (from basemap) (2.3.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from pyproj<3.8,>=3.0->basemap) (2025.11.12)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: esda in /usr/local/lib/python3.12/dist-packages (2.8.0)
# Requirement already satisfied: geopandas>=0.14 in /usr/local/lib/python3.12/dist-packages (from esda) (1.1.1)
# Requirement already satisfied: libpysal>=4.12 in /usr/local/lib/python3.12/dist-packages (from esda) (4.13.0)
# Requirement already satisfied: numpy>=1.26 in /usr/local/lib/python3.12/dist-packages (from esda) (2.0.2)
# Requirement already satisfied: pandas>=2.1 in /usr/local/lib/python3.12/dist-packages (from esda) (2.2.2)
# Requirement already satisfied: scikit-learn>=1.4 in /usr/local/lib/python3.12/dist-packages (from esda) (1.6.1)
# Requirement already satisfied: scipy>=1.12 in /usr/local/lib/python3.12/dist-packages (from esda) (1.16.3)
# Requirement already satisfied: shapely>=2.1 in /usr/local/lib/python3.12/dist-packages (from esda) (2.1.2)
# Requirement already satisfied: pyogrio>=0.7.2 in /usr/local/lib/python3.12/dist-packages (from geopandas>=0.14->esda) (0.11.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from geopandas>=0.14->esda) (25.0)
# Requirement already satisfied: pyproj>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from geopandas>=0.14->esda) (3.7.2)
# Requirement already satisfied: beautifulsoup4>=4.10 in /usr/local/lib/python3.12/dist-packages (from libpysal>=4.12->esda) (4.13.5)
# Requirement already satisfied: platformdirs>=2.0.2 in /usr/local/lib/python3.12/dist-packages (from libpysal>=4.12->esda) (4.5.0)
# Requirement already satisfied: requests>=2.27 in /usr/local/lib/python3.12/dist-packages (from libpysal>=4.12->esda) (2.32.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.1->esda) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.1->esda) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.1->esda) (2025.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.4->esda) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.4->esda) (3.6.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4>=4.10->libpysal>=4.12->esda) (2.8)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4>=4.10->libpysal>=4.12->esda) (4.15.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from pyogrio>=0.7.2->geopandas>=0.14->esda) (2025.11.12)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=2.1->esda) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.27->libpysal>=4.12->esda) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.27->libpysal>=4.12->esda) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.27->libpysal>=4.12->esda) (2.5.0)

# %% [markdown]
# # **Import Library**

# %%
import geopandas as gpd
import matplotlib.pyplot as plt
import pandas as pd
import cartopy.crs as ccrs
import cartopy.feature as cfeature
from mpl_toolkits.basemap import Basemap
from matplotlib.patches import Patch
from matplotlib.colors import ListedColormap
from matplotlib import cm, colors

# %% [markdown]
# # **Read Dataset**

# %%
# Memuat dataset
# Load dataset gempa
dataset1 = "https://raw.githubusercontent.com/arifadli/DatasetRepository/main/Disertation/Indonesia/Indonesia_EQ_Part_1.csv"
dataset2 = "https://raw.githubusercontent.com/arifadli/DatasetRepository/main/Disertation/Indonesia/Indonesia_EQ_Part_2.csv"

# Load each dataset
df1 = pd.read_csv(dataset1)
df2 = pd.read_csv(dataset2)

# Concatenate the datasets
merged_df = pd.concat([df1, df2], ignore_index=True)

data_gempa = merged_df

# Mengubah kolom "time" menjadi tipe data datetime
data_gempa['time'] = pd.to_datetime(data_gempa['time'])

# Memisahkan kolom "time" menjadi dua kolom terpisah: "date" dan "time"
data_gempa['date'] = data_gempa['time'].dt.date
data_gempa['time'] = data_gempa['time'].dt.time

# Mengonversi kolom "time" menjadi string dengan format HH:MM:SS
data_gempa['time'] = data_gempa['time'].apply(lambda x: x.strftime('%H:%M:%S'))

selected_columns = ['time','date', 'latitude', 'longitude', 'place' ,'depth', 'mag', 'magType', 'type']
data_gempa = data_gempa.loc[:, selected_columns]

# Menampilkan lima baris pertama setelah pemisahan
data_gempa.head(5)
# Out:
#        time        date  latitude  longitude  \
# 0  11:05:59  1994-12-31     2.475    126.188
# 1  21:28:48  1994-12-30    -5.092    103.514
# 2  03:46:35  1994-12-30    -9.697    124.116
# 3  06:15:10  1994-12-29    -8.608    119.387
# 4  04:33:53  1994-12-29    -5.112    102.689
#
#                                                place  depth  mag magType  \
# 0  173 km NE of Laikit, Laikit II (Dimembe), Indo...   86.8  5.2      mb
# 1                121 km SSE of Pagar Alam, Indonesia   99.0  5.1      mb
# 2                         25 km NW of Soe, Indonesia   78.5  4.8      mb
# 3                       11 km W of Komodo, Indonesia  142.2  4.2      mb
# 4                135 km SSW of Pagar Alam, Indonesia   60.7  5.4      mb
#
#          type
# 0  earthquake
# 1  earthquake
# 2  earthquake
# 3  earthquake
# 4  earthquake

# %%
# 1. Gabungkan kolom date + time menjadi datetime_combined
data_gempa['datetime_combined'] = (
    data_gempa['date'].astype(str) + ' ' + data_gempa['time'].astype(str)
)

# 2. Ubah ke datetime
data_gempa['datetime_combined'] = pd.to_datetime(data_gempa['datetime_combined'])

# 3. Buat kolom UNIX timestamp (dalam detik)
data_gempa['timestamp'] = data_gempa['datetime_combined'].astype('int64') // 10**9
# 4. Buat kolom timestamp_dt untuk tipe datetime
data_gempa['timestamp_dt'] = pd.to_datetime(data_gempa['datetime_combined'])

# %%
data_gempa.head()
# Out:
#        time        date  latitude  longitude  \
# 0  11:05:59  1994-12-31     2.475    126.188
# 1  21:28:48  1994-12-30    -5.092    103.514
# 2  03:46:35  1994-12-30    -9.697    124.116
# 3  06:15:10  1994-12-29    -8.608    119.387
# 4  04:33:53  1994-12-29    -5.112    102.689
#
#                                                place  depth  mag magType  \
# 0  173 km NE of Laikit, Laikit II (Dimembe), Indo...   86.8  5.2      mb
# 1                121 km SSE of Pagar Alam, Indonesia   99.0  5.1      mb
# 2                         25 km NW of Soe, Indonesia   78.5  4.8      mb
# 3                       11 km W of Komodo, Indonesia  142.2  4.2      mb
# 4                135 km SSW of Pagar Alam, Indonesia   60.7  5.4      mb
#
#          type   datetime_combined  timestamp        timestamp_dt
# 0  earthquake 1994-12-31 11:05:59  788871959 1994-12-31 11:05:59
# 1  earthquake 1994-12-30 21:28:48  788822928 1994-12-30 21:28:48
# 2  earthquake 1994-12-30 03:46:35  788759195 1994-12-30 03:46:35
# 3  earthquake 1994-12-29 06:15:10  788681710 1994-12-29 06:15:10
# 4  earthquake 1994-12-29 04:33:53  788675633 1994-12-29 04:33:53

# %% [markdown]
# # **Feature Engineering**

# %%
import pandas as pd

# ==========================================
# Asumsi: data_gempa sudah dimuat sebelumnya
# ==========================================

df = data_gempa.copy()

# ------------------------------------------
# 1. Gabungkan kolom date + time
# ------------------------------------------
df['datetime_combined'] = df['date'].astype(str) + ' ' + df['time'].astype(str)
df['datetime_combined'] = pd.to_datetime(df['datetime_combined'])

# ------------------------------------------
# 2. Buat kolom timestamp (UNIX) dan datetime khusus
# ------------------------------------------
df['timestamp'] = df['datetime_combined'].astype('int64') // 10**9
df['timestamp_dt'] = pd.to_datetime(df['datetime_combined'])  # gunakan untuk .dt accessor

# ------------------------------------------
# 3. Fungsi untuk menambah fitur berdasarkan waktu
# ------------------------------------------
def create_features(df: pd.DataFrame) -> pd.DataFrame:
    df = df.copy()
    df['hour'] = df.timestamp_dt.dt.hour
    df['dayofweek'] = df.timestamp_dt.dt.dayofweek
    df['month'] = df.timestamp_dt.dt.month
    df['year'] = df.timestamp_dt.dt.year
    df['dayofyear'] = df.timestamp_dt.dt.dayofyear
    df['dayofmonth'] = df.timestamp_dt.dt.day
    df['weekofyear'] = df.timestamp_dt.dt.isocalendar().week
    df['quarter'] = df.timestamp_dt.dt.quarter
    df['season'] = df['month'] % 12 // 3 + 1
    return df

# ------------------------------------------
# 4. Fungsi untuk menambah lag features
# ------------------------------------------
def add_lags(df: pd.DataFrame) -> pd.DataFrame:
    df = df.copy()
    df['mag_5eq_lag'] = df.mag.shift(3)
    df['mag_10eq_lag'] = df.mag.shift(6)
    df['mag_15eq_lag'] = df.mag.shift(9)

    df['depth_5eq_lag'] = df.depth.shift(3)
    df['depth_10eq_lag'] = df.depth.shift(6)
    df['depth_15eq_lag'] = df.depth.shift(9)

    # Selisih waktu antar gempa dalam hari
    df['time_diff'] = df.timestamp_dt.diff().dt.total_seconds() / 86400
    return df

# ------------------------------------------
# 5. Fungsi untuk menambah rolling windows
# ------------------------------------------
def add_rolling_windows(df: pd.DataFrame) -> pd.DataFrame:
    df = df.copy()
    # Rolling mag
    for window in [5,10,15]:
        df[f'mag_{window}eq_avg'] = df.mag.rolling(window=window, min_periods=1).mean()
        df[f'mag_{window}eq_min'] = df.mag.rolling(window=window, min_periods=1).min()
        df[f'mag_{window}eq_max'] = df.mag.rolling(window=window, min_periods=1).max()
        df[f'mag_{window}eq_std'] = df.mag.rolling(window=window, min_periods=1).std()
        df[f'depth_{window}eq_avg'] = df.depth.rolling(window=window, min_periods=1).mean()
        df[f'depth_{window}eq_min'] = df.depth.rolling(window=window, min_periods=1).min()
        df[f'depth_{window}eq_max'] = df.depth.rolling(window=window, min_periods=1).max()
        df[f'depth_{window}eq_std'] = df.depth.rolling(window=window, min_periods=1).std()

    # Perubahan 7,14,21 hari
    for diff_day in [7,14,21]:
        df[f'mag_{diff_day}day_avg_change'] = df.mag.diff(diff_day)
        df[f'depth_{diff_day}day_avg_change'] = df.depth.diff(diff_day)

   # Isi NaN setelah operasi diff, shift, rolling
    df.ffill(inplace=True)
    df.bfill(inplace=True)


    return df

# ------------------------------------------
# 6. Terapkan semua fungsi
# ------------------------------------------
df = create_features(df)
df = add_lags(df)
df = add_rolling_windows(df)

# ------------------------------------------
# 7. Tampilkan hasil
# ------------------------------------------
df.head(20)
# Out:
#         time        date  latitude  longitude  \
# 0   11:05:59  1994-12-31     2.475    126.188
# 1   21:28:48  1994-12-30    -5.092    103.514
# 2   03:46:35  1994-12-30    -9.697    124.116
# 3   06:15:10  1994-12-29    -8.608    119.387
# 4   04:33:53  1994-12-29    -5.112    102.689
# 5   22:39:23  1994-12-28     5.211    126.316
# 6   15:01:47  1994-12-28   -10.585    121.723
# 7   03:15:16  1994-12-28     3.745    128.215
# 8   21:59:50  1994-12-27     4.295    125.924
# 9   16:43:03  1994-12-27     0.772    127.232
# 10  13:28:25  1994-12-26     1.212    117.980
# 11  20:17:13  1994-12-25    -2.352    138.867
# 12  07:18:41  1994-12-25    -1.625    127.267
# 13  21:43:04  1994-12-24    -3.207    139.568
# 14  17:46:55  1994-12-24     5.520    127.254
# 15  04:57:03  1994-12-24    -8.893    120.139
# 16  00:28:28  1994-12-23    -4.995    133.503
# 17  17:43:30  1994-12-21     0.816    126.230
# 18  11:08:50  1994-12-20    -6.134    103.933
# 19  06:21:04  1994-12-19    -9.415    124.331
#
#                                                 place  depth  mag magType  \
# 0   173 km NE of Laikit, Laikit II (Dimembe), Indo...   86.8  5.2      mb
# 1                 121 km SSE of Pagar Alam, Indonesia   99.0  5.1      mb
# 2                          25 km NW of Soe, Indonesia   78.5  4.8      mb
# 3                        11 km W of Komodo, Indonesia  142.2  4.2      mb
# 4                 135 km SSW of Pagar Alam, Indonesia   60.7  5.4      mb
# 5                 96 km ESE of Sarangani, Philippines   72.5  5.0      mb
# 6                   190 km ESE of Waingapu, Indonesia   70.9  5.1      mb
# 7                       224 km N of Tobelo, Indonesia   33.0  4.9      mb
# 8                132 km SSE of Sarangani, Philippines  182.0  4.9      mb
# 9                       17 km W of Ternate, Indonesia  176.0  4.5      mb
# 10                   131 km NNE of Bontang, Indonesia   33.0  4.9      mb
# 11                     198 km W of Abepura, Indonesia   33.0  5.3      mw
# 12                     250 km NNW of Ambon, Indonesia   33.0  4.8      mb
# 13                   136 km WSW of Abepura, Indonesia  102.0  4.9      mb
# 14              151 km SE of Pondaguitan, Philippines  112.9  4.7      mb
# 15                      47 km SW of Ruteng, Indonesia  204.5  4.3      mb
# 16                       108 km NE of Tual, Indonesia   33.0  5.4      mw
# 17                     128 km W of Ternate, Indonesia   35.8  5.1      mw
# 18            166 km WSW of Bandar Lampung, Indonesia   37.0  5.5      mb
# 19                 16 km WNW of Kefamenanu, Indonesia   97.4  4.5      mb
#
#           type   datetime_combined  ...  depth_15eq_avg depth_15eq_min  \
# 0   earthquake 1994-12-31 11:05:59  ...       86.800000           86.8
# 1   earthquake 1994-12-30 21:28:48  ...       92.900000           86.8
# 2   earthquake 1994-12-30 03:46:35  ...       88.100000           78.5
# 3   earthquake 1994-12-29 06:15:10  ...      101.625000           78.5
# 4   earthquake 1994-12-29 04:33:53  ...       93.440000           60.7
# 5   earthquake 1994-12-28 22:39:23  ...       89.950000           60.7
# 6   earthquake 1994-12-28 15:01:47  ...       87.228571           60.7
# 7   earthquake 1994-12-28 03:15:16  ...       80.450000           33.0
# 8   earthquake 1994-12-27 21:59:50  ...       91.733333           33.0
# 9   earthquake 1994-12-27 16:43:03  ...      100.160000           33.0
# 10  earthquake 1994-12-26 13:28:25  ...       94.054545           33.0
# 11  earthquake 1994-12-25 20:17:13  ...       88.966667           33.0
# 12  earthquake 1994-12-25 07:18:41  ...       84.661538           33.0
# 13  earthquake 1994-12-24 21:43:04  ...       85.900000           33.0
# 14  earthquake 1994-12-24 17:46:55  ...       87.700000           33.0
# 15  earthquake 1994-12-24 04:57:03  ...       95.546667           33.0
# 16  earthquake 1994-12-23 00:28:28  ...       91.146667           33.0
# 17  earthquake 1994-12-21 17:43:30  ...       88.300000           33.0
# 18  earthquake 1994-12-20 11:08:50  ...       81.286667           33.0
# 19  earthquake 1994-12-19 06:21:04  ...       83.733333           33.0
#
#     depth_15eq_max  depth_15eq_std  mag_7day_avg_change  \
# 0             86.8        8.626703                 -0.3
# 1             99.0        8.626703                 -0.3
# 2             99.0       10.311644                 -0.3
# 3            142.2       28.330005                 -0.3
# 4            142.2       30.609035                 -0.3
# 5            142.2       28.681196                 -0.3
# 6            142.2       27.154233                 -0.3
# 7            142.2       31.616587                 -0.3
# 8            182.0       44.949750                 -0.2
# 9            182.0       50.060657                 -0.3
# 10           182.0       51.628526                  0.7
# 11           182.0       52.285985                 -0.1
# 12           182.0       52.411346                 -0.2
# 13           182.0       50.567959                 -0.2
# 14           182.0       49.224660                 -0.2
# 15           204.5       57.719035                 -0.6
# 16           204.5       59.910992                  0.9
# 17           204.5       61.546928                  0.2
# 18           204.5       60.957255                  0.2
# 19           204.5       60.808278                 -0.3
#
#     depth_7day_avg_change  mag_14day_avg_change  depth_14day_avg_change  \
# 0                   -53.8                  -0.5                    26.1
# 1                   -53.8                  -0.5                    26.1
# 2                   -53.8                  -0.5                    26.1
# 3                   -53.8                  -0.5                    26.1
# 4                   -53.8                  -0.5                    26.1
# 5                   -53.8                  -0.5                    26.1
# 6                   -53.8                  -0.5                    26.1
# 7                   -53.8                  -0.5                    26.1
# 8                    83.0                  -0.5                    26.1
# 9                    97.5                  -0.5                    26.1
# 10                 -109.2                  -0.5                    26.1
# 11                  -27.7                  -0.5                    26.1
# 12                  -39.5                  -0.5                    26.1
# 13                   31.1                  -0.5                    26.1
# 14                   79.9                  -0.5                    26.1
# 15                   22.5                  -0.8                   105.5
# 16                 -143.0                   0.6                   -45.5
# 17                    2.8                   0.9                  -106.4
# 18                    4.0                   0.1                   -23.7
# 19                   64.4                  -0.5                    24.9
#
#     mag_21day_avg_change  depth_21day_avg_change
# 0                   -0.7                   -53.8
# 1                   -0.7                   -53.8
# 2                   -0.7                   -53.8
# 3                   -0.7                   -53.8
# 4                   -0.7                   -53.8
# 5                   -0.7                   -53.8
# 6                   -0.7                   -53.8
# 7                   -0.7                   -53.8
# 8                   -0.7                   -53.8
# 9                   -0.7                   -53.8
# 10                  -0.7                   -53.8
# 11                  -0.7                   -53.8
# 12                  -0.7                   -53.8
# 13                  -0.7                   -53.8
# 14                  -0.7                   -53.8
# 15                  -0.7                   -53.8
# 16                  -0.7                   -53.8
# 17                  -0.7                   -53.8
# 18                  -0.7                   -53.8
# 19                  -0.7                   -53.8
#
# [20 rows x 58 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31745 entries, 0 to 31744
# Data columns (total 58 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   time                    31745 non-null  object
#  1   date                    31745 non-null  object
#  2   latitude                31745 non-null  float64
#  3   longitude               31745 non-null  float64
#  4   place                   31745 non-null  object
#  5   depth                   31745 non-null  float64
#  6   mag                     31745 non-null  float64
#  7   magType                 31745 non-null  object
#  8   type                    31745 non-null  object
#  9   datetime_combined       31745 non-null  datetime64[ns]
#  10  timestamp               31745 non-null  int64
#  11  timestamp_dt            31745 non-null  datetime64[ns]
#  12  hour                    31745 non-null  int32
#  13  dayofweek               31745 non-null  int32
#  14  month                   31745 non-null  int32
#  15  year                    31745 non-null  int32
#  16  dayofyear               31745 non-null  int32
#  17  dayofmonth              31745 non-null  int32
#  18  weekofyear              31745 non-null  UInt32
#  19  quarter                 31745 non-null  int32
#  20  season                  31745 non-null  int32
#  21  mag_5eq_lag             31745 non-null  float64
#  22  mag_10eq_lag            31745 non-null  float64
#  23  mag_15eq_lag            31745 non-null  float64
#  24  depth_5eq_lag           31745 non-null  float64
#  25  depth_10eq_lag          31745 non-null  float64
#  26  depth_15eq_lag          31745 non-null  float64
#  27  time_diff               31745 non-null  float64
#  28  mag_5eq_avg             31745 non-null  float64
#  29  mag_5eq_min             31745 non-null  float64
#  30  mag_5eq_max             31745 non-null  float64
#  31  mag_5eq_std             31745 non-null  float64
#  32  depth_5eq_avg           31745 non-null  float64
#  33  depth_5eq_min           31745 non-null  float64
#  34  depth_5eq_max           31745 non-null  float64
#  35  depth_5eq_std           31745 non-null  float64
#  36  mag_10eq_avg            31745 non-null  float64
#  37  mag_10eq_min            31745 non-null  float64
#  38  mag_10eq_max            31745 non-null  float64
#  39  mag_10eq_std            31745 non-null  float64
#  40  depth_10eq_avg          31745 non-null  float64
#  41  depth_10eq_min          31745 non-null  float64
#  42  depth_10eq_max          31745 non-null  float64
#  43  depth_10eq_std          31745 non-null  float64
#  44  mag_15eq_avg            31745 non-null  float64
#  45  mag_15eq_min            31745 non-null  float64
#  46  mag_15eq_max            31745 non-null  float64
#  47  mag_15eq_std            31745 non-null  float64
#  48  depth_15eq_avg          31745 non-null  float64
#  49  depth_15eq_min          31745 non-null  float64
#  50  depth_15eq_max          31745 non-null  float64
#  51  depth_15eq_std          31745 non-null  float64
#  52  mag_7day_avg_change     31745 non-null  float64
#  53  depth_7day_avg_change   31745 non-null  float64
#  54  mag_14day_avg_change    31745 non-null  float64
#  55  depth_14day_avg_change  31745 non-null  float64
#  56  mag_21day_avg_change    31745 non-null  float64
#  57  depth_21day_avg_change  31745 non-null  float64
# dtypes: UInt32(1), datetime64[ns](2), float64(41), int32(8), int64(1), object(5)
# memory usage: 13.0+ MB

# %%
df.describe()
# Out:
#            latitude     longitude         depth           mag  \
# count  31745.000000  31745.000000  31745.000000  31745.000000
# mean      -2.660768    121.702247     85.231434      4.645433
# min      -11.000000   -120.844833      0.900000      2.700000
# 25%       -6.823000    117.114000     33.000000      4.300000
# 50%       -2.942000    126.107000     33.000000      4.600000
# 75%        1.257000    129.306000    100.000000      4.900000
# max       35.544667    140.999000    675.500000      9.100000
# std        4.524948     12.385402    104.836843      0.518845
#
#                    datetime_combined     timestamp  \
# count                          31745  3.174500e+04
# mean   1994-08-31 06:57:19.259473920  7.783162e+08
# min              1974-01-01 14:07:40  1.262813e+08
# 25%              1988-02-20 01:25:58  5.723188e+08
# 50%              1996-04-30 17:21:39  8.308849e+08
# 75%              2002-04-05 02:41:17  1.017974e+09
# max              2005-12-31 22:46:53  1.136069e+09
# std                              NaN  2.735997e+08
#
#                         timestamp_dt          hour     dayofweek  \
# count                          31745  31745.000000  31745.000000
# mean   1994-08-31 06:57:19.259473920     11.761789      3.034872
# min              1974-01-01 14:07:40      0.000000      0.000000
# 25%              1988-02-20 01:25:58      6.000000      1.000000
# 50%              1996-04-30 17:21:39     12.000000      3.000000
# 75%              2002-04-05 02:41:17     18.000000      5.000000
# max              2005-12-31 22:46:53     23.000000      6.000000
# std                              NaN      6.871839      2.034794
#
#               month  ...  depth_15eq_avg  depth_15eq_min  depth_15eq_max  \
# count  31745.000000  ...    31745.000000    31745.000000    31745.000000
# mean       6.461931  ...       85.236629       25.201017      326.045031
# min        1.000000  ...       10.000000        0.900000       10.000000
# 25%        4.000000  ...       59.966667       16.900000      178.400000
# 50%        6.000000  ...       82.473333       32.000000      290.300000
# 75%       10.000000  ...      107.400000       33.000000      507.600000
# max       12.000000  ...      562.486667       86.800000      675.500000
# std        3.426909  ...       36.694934        9.607164      182.283215
#
#        depth_15eq_std  mag_7day_avg_change  depth_7day_avg_change  \
# count    31745.000000         31745.000000           31745.000000
# mean        87.415889            -0.000120              -0.016223
# min          0.000000            -4.300000            -642.500000
# 25%         48.535051            -0.400000             -36.300000
# 50%         76.927038             0.000000               0.000000
# 75%        130.985687             0.400000              36.500000
# max        288.040419             3.900000             642.500000
# std         51.873624             0.672941             144.338979
#
#        mag_14day_avg_change  depth_14day_avg_change  mag_21day_avg_change  \
# count          31745.000000            31745.000000          31745.000000
# mean              -0.000280                0.002882             -0.000583
# min               -5.300000             -642.100000             -5.000000
# 25%               -0.400000              -36.500000             -0.400000
# 50%                0.000000                0.000000              0.000000
# 75%                0.400000               37.000000              0.400000
# max                4.290000              642.500000              4.700000
# std                0.678758              145.420554              0.679723
#
#        depth_21day_avg_change
# count            31745.000000
# mean                -0.027932
# min               -641.300000
# 25%                -37.100000
# 50%                  0.000000
# 75%                 37.100000
# max                642.500000
# std                145.275105
#
# [8 rows x 53 columns]

# %%
import pandas as pd

# Kolom target
target_col = 'mag'

# Kolom fitur (exclude target dan kolom datetime)
exclude_cols = ['mag', 'datetime_combined', 'timestamp_dt', 'timestamp', 'date', 'time']
feature_cols = [col for col in df.columns if col not in exclude_cols]

# --- Tabel Fitur ---
# Jumlah kolom per baris agar ringkas
cols_per_row = 5
feature_rows = [feature_cols[i:i+cols_per_row] for i in range(0, len(feature_cols), cols_per_row)]
feature_table = pd.DataFrame(feature_rows)

# --- Tabel Target ---
target_table = pd.DataFrame([[target_col]], columns=['Target'])

# Tampilkan
print("=== Tabel Fitur ===")
display(feature_table)

print("=== Tabel Target ===")
display(target_table.style.set_properties(**{'font-weight': 'bold'}))
# Out:
# === Tabel Fitur ===
#                        0                       1                      2  \
# 0               latitude               longitude                  place
# 1                   type                    hour              dayofweek
# 2              dayofyear              dayofmonth             weekofyear
# 3            mag_5eq_lag            mag_10eq_lag           mag_15eq_lag
# 4         depth_15eq_lag               time_diff            mag_5eq_avg
# 5            mag_5eq_std           depth_5eq_avg          depth_5eq_min
# 6           mag_10eq_avg            mag_10eq_min           mag_10eq_max
# 7         depth_10eq_min          depth_10eq_max         depth_10eq_std
# 8           mag_15eq_max            mag_15eq_std         depth_15eq_avg
# 9         depth_15eq_std     mag_7day_avg_change  depth_7day_avg_change
# 10  mag_21day_avg_change  depth_21day_avg_change                   None
#
#                        3                       4
# 0                  depth                 magType
# 1                  month                    year
# 2                quarter                  season
# 3          depth_5eq_lag          depth_10eq_lag
# 4            mag_5eq_min             mag_5eq_max
# 5          depth_5eq_max           depth_5eq_std
# 6           mag_10eq_std          depth_10eq_avg
# 7           mag_15eq_avg            mag_15eq_min
# 8         depth_15eq_min          depth_15eq_max
# 9   mag_14day_avg_change  depth_14day_avg_change
# 10                  None                    None
# === Tabel Target ===
# <style type="text/css">
# #T_c7a0d_row0_col0 {
#   font-weight: bold;
# }
# </style>
# <table id="T_c7a0d" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c7a0d_level0_col0" class="col_heading level0 col0" >Target</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c7a0d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c7a0d_row0_col0" class="data row0 col0" >mag</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # **Split Train, Validation and Testing**

# %%
import pandas as pd
import matplotlib.pyplot as plt

# =============================
# 1. Pastikan datetime format benar
# =============================
df['datetime_combined'] = pd.to_datetime(df['datetime_combined'])
df = df.sort_values(by='datetime_combined').reset_index(drop=True)

# =============================
# 2. Split berdasarkan WAKTU (No Data Leakage)
# =============================
min_t = df['datetime_combined'].min()
max_t = df['datetime_combined'].max()
total_range = max_t - min_t

train_cut = min_t + total_range * 0.80
val_cut   = min_t + total_range * 0.90

train = df[df['datetime_combined'] <= train_cut]
val   = df[(df['datetime_combined'] > train_cut) & (df['datetime_combined'] <= val_cut)]
test  = df[df['datetime_combined'] > val_cut]

# =============================
# 3. Plot data
# =============================
plt.figure(figsize=(14,6))
plt.plot(train['datetime_combined'], train['mag'], label='Training Set', alpha=0.7)
plt.plot(val['datetime_combined'], val['mag'], label='Validation Set', alpha=0.7)
plt.plot(test['datetime_combined'], test['mag'], label='Test Set', alpha=0.7)

plt.legend()
plt.xlabel("Time")
plt.ylabel("Magnitude")
plt.title("Time-Based Split (No Overlap)")
plt.grid(True)
plt.show()

# =============================
# 4. Print Rentang Waktu
# =============================
print("=== RENTANG WAKTU TANPA OVERLAP ===")
print(f"Train   ({len(train)} data): {train['datetime_combined'].min().date()} → {train['datetime_combined'].max().date()}")
print(f"Val     ({len(val)} data):   {val['datetime_combined'].min().date()} → {val['datetime_combined'].max().date()}")
print(f"Test    ({len(test)} data):  {test['datetime_combined'].min().date()} → {test['datetime_combined'].max().date()}")
# Out:
# === RENTANG WAKTU TANPA OVERLAP ===
# Train   (20554 data): 1974-01-01 → 1999-08-08
# Val     (4024 data):   1999-08-09 → 2002-10-19
# Test    (7167 data):  2002-10-20 → 2005-12-31

# %% [markdown]
# # **Linear Regression Model Prediction**

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score, accuracy_score, f1_score, recall_score, precision_score
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

# =========================================
# 1. Definisikan Fitur dan Target
# =========================================
target_col = 'mag'

exclude_cols = ['mag', 'datetime_combined', 'timestamp_dt', 'timestamp', 'date', 'time', 'place', 'mb']

feature_cols = [col for col in df.columns if col not in exclude_cols]
feature_cols = df[feature_cols].select_dtypes(include=[np.number]).columns.tolist()

X = df[feature_cols].values
y = df[target_col].values

# =========================================
# 2. Split Data sesuai urutan waktu
# =========================================
n = len(df)
n_train = int(n * 0.80)
n_val   = int(n * 0.05)
n_test  = n - n_train - n_val

X_train = X[:n_train]
y_train = y[:n_train]

X_val = X[n_train:n_train+n_val]
y_val = y[n_train:n_train+n_val]

X_test = X[n_train+n_val:]
y_test = y[n_train+n_val:]

# =========================================
# 3. Normalisasi Data (opsional untuk Linear Regression)
# =========================================
scaler = MinMaxScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_val_scaled = scaler.transform(X_val)
X_test_scaled = scaler.transform(X_test)

# =========================================
# 4. Linear Regression
# =========================================
model_lr = LinearRegression()
model_lr.fit(X_train_scaled, y_train)

# =========================================
# 5. Prediksi
# =========================================
y_train_pred = model_lr.predict(X_train_scaled)
y_val_pred = model_lr.predict(X_val_scaled)
y_test_pred = model_lr.predict(X_test_scaled)

# =========================================
# 6. Fungsi Evaluasi Lengkap
# =========================================
def evaluate_all(y_true, y_pred, label, threshold=5):
    rmse = np.sqrt(mean_squared_error(y_true, y_pred))
    mae = mean_absolute_error(y_true, y_pred)
    r2 = r2_score(y_true, y_pred)

    y_true_class = (y_true >= threshold).astype(int)
    y_pred_class = (y_pred >= threshold).astype(int)
    acc = accuracy_score(y_true_class, y_pred_class)
    f1 = f1_score(y_true_class, y_pred_class)
    recall = recall_score(y_true_class, y_pred_class)
    precision = precision_score(y_true_class, y_pred_class)

    print(f"\n--- {label} ---")
    print(f"RMSE       : {rmse:.4f}")
    print(f"MAE        : {mae:.4f}")
    print(f"R²         : {r2:.4f}")


# =========================================
# 7. Evaluasi Semua Fase
# =========================================
def evaluate_phase(y_true, y_pred, phase):
    evaluate_all(y_true[:30], y_pred[:30], f"{phase} (30 Hari)")

evaluate_phase(y_train, y_train_pred, "Training")
evaluate_phase(y_val, y_val_pred, "Validation")
evaluate_phase(y_test, y_test_pred, "Testing")

# =========================================
# 8. Visualisasi Hasil Prediksi (30 Hari)
# =========================================
plt.figure(figsize=(10,6))
plt.plot(y_test[:30], label='Aktual', color='blue')
plt.plot(y_test_pred[:30], label='Prediksi', color='orange', linestyle='--')
plt.title('Aktual vs Prediksi Magnitudo (30 Hari) - Linear Regression')
plt.xlabel('Hari')
plt.ylabel('Magnitudo')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# --- Training (30 Hari) ---
# RMSE       : 0.1515
# MAE        : 0.1246
# R²         : 0.8233
#
# --- Validation (30 Hari) ---
# RMSE       : 0.1681
# MAE        : 0.1354
# R²         : 0.8784
#
# --- Testing (30 Hari) ---
# RMSE       : 0.2561
# MAE        : 0.2102
# R²         : 0.7538
